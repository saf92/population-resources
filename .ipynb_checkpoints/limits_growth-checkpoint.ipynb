# %%
# Packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
# Functions and classes

class plotting:
    '''
    Class for plotting. 
    '''
    def __init__(self,ax,myxlabel,myylabel,font_sizes,leg):
        self.ax = ax # Axis
        self.myxlabel = myxlabel # x-label
        self.myylabel = myylabel # y-label
        self.font_sizes = font_sizes # font-sizes 
        self.leg = leg # Legend 

    def add_labels(self):
        '''
        Adds labels, grid and optional legend to plot.
        Inputs: 
        ax - plotting object
        myxlabel - xlabel string
        myylabel - ylabel string
        font_sizes - array of size 5 of fontsizes for xlabel string, 
        ylabel string, xticks, yticks and legend
        leg - if 1 put in the legend, otherwise do not
        Output: ax - plotting object with the added inputs
        '''
        self.ax.set_xlabel(self.myxlabel,fontsize=self.font_sizes[0])
        self.ax.set_ylabel(self.myylabel,fontsize=self.font_sizes[1])
        self.ax.grid(color='grey', linestyle='--', linewidth=0.5)
        self.ax.tick_params(axis='x', labelsize=self.font_sizes[2])
        self.ax.tick_params(axis='y', labelsize=self.font_sizes[3])
        if(self.leg==1):
            self.ax.legend(fontsize=self.font_sizes[4])
        return self.ax


def pop_res_model(n,P_0,R_0,dt,a,b,c,d):
    '''
    a: alpha, b: beta, c: gamma, d: delta
    Euler's Method
    '''
    P = P_0
    R = R_0
    
    Ps = [P]
    Rs = [R]
    
    for i in range(n-1):
        P = P + dt*(P*(a-b*P/R))
        R = R + dt*(-c*P+d)
    
        Ps.append(P)
        Rs.append(R)
    
    Ps = np.asarray(Ps, float)
    Rs = np.asarray(Rs, float)

    return Ps, Rs

def pop_res_model1(n,P_0,R_0,dt,a,b,c,d):
    '''
    a: alpha, b: beta, c: gamma, d: delta
    Runge-Kutta
    '''
    P = P_0
    R = R_0
    
    Ps = [P]
    Rs = [R]
    
    for i in range(n-1):
        k1P, k1R = (P*(a-b*P/R))*dt,dt*(-c*P+d)
        P, R = P+1/2*k1P, R+1/2*k1R
        k2P, k2R = (P*(a-b*P/R))*dt,dt*(-c*P+d)
        P, R = P+1/2*k2P, R+1/2*k2R
        k3P, k3R = (P*(a-b*P/R))*dt,dt*(-c*P+d)
        P, R = P+k3P, R+k3R
        k4P, k4R = (P*(a-b*P/R))*dt,dt*(-c*P+d)
        P = P + 1/6*(k1P+2*k2P+2*k3P+k4P)
        R = R + 1/6*(k1R+2*k2R+2*k3R+k4R)
        Ps.append(P)
        Rs.append(R)
    
    Ps = np.asarray(Ps, float)
    Rs = np.asarray(Rs, float)

    return Ps, Rs

def pop_res_eqns(X_0, t, a, b, c, d):
    P, R = X_0
    Pdot = P*(a - b*P/R)
    Rdot = d - c*P
    Xdot = [Pdot, Rdot]
    return Xdot

# %%
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.odeint.html

n = 10**4
dt = 10**-2
P_0 = 10**3
R_0 = 10**6
X_0 = [P_0,R_0]
a = 1
b = 1
c = 1
d = 10**2
t = np.cumsum(np.ones(n)*dt)

params1 = (0.1,1,1,10**2)

sol = odeint(pop_res_eqns, X_0, t, args=params1)

fig, ax = plt.subplots(1,2,figsize=(10,3)) 

ax[0].plot(t,sol[:, 0], label = 'Population')
ax[1].plot(t,sol[:, 1], label = 'Resources')
leg=1
font_sizes = [12,12,12,12,12]
labels=['Time','',font_sizes,leg]
plotting(ax[0],*labels).add_labels()
plotting(ax[1],*labels).add_labels()
# Out:
# <Axes: xlabel='Time'>

# %%
a = 0.5
b = 0.1
c = 1
d = 10**2
fixed_point = np.array([[d/c, b*d/a*c]])
print(fixed_point)
c_k = 2
p_l, p_u = -0.5*fixed_point[0][0], 2*fixed_point[0][0]
r_l, r_u = -0.5*fixed_point[0][1], 2*fixed_point[0][1]

k = 200
p = np.linspace(p_l, p_u, k)
r = np.linspace(r_l, r_u, k)
P, R = np.meshgrid(p, r)

Pdot = P*(a - b*P/R)
Rdot = d - c*P

fig, ax = plt.subplots()
ax.streamplot(P, R, Pdot, Rdot)
ax.scatter(*fixed_point.T, color="r")

leg=0
font_sizes = [12,12,12,12,12]
labels=[r'$P$',r'$R$',font_sizes,leg]
plotting(ax,*labels).add_labels()
# Out:
# [[100.  20.]]
# <Axes: xlabel='$P$', ylabel='$R$'>

# %%
fig, ax = plt.subplots() 

ax.plot(sol[:,0], sol[:,1], label = '')
ax.plot(d/c, b*d/a*c,'o')

leg=0
font_sizes = [12,12,12,12,12]
labels=[r'$P$',r'$R$',font_sizes,leg]
plotting(ax,*labels).add_labels()
# Out:
# <Axes: xlabel='$P$', ylabel='$R$'>

# %% [markdown]
# https://ourworldindata.org/grapher/population

# %%
data = pd.read_csv('population.csv')

# %%
data1 = data.values

ind = np.where(data1[:,0] == 'World')

# %%
dates = data1[:,2][ind]
popn = data1[:,3][ind]

# %%
dt = 10**-2

# %%
n1 = dates[-1]-dates[0]
dates1 = np.arange(dates[0],dates[-1],1)
P_01 = popn[0]
R_01 = 3*10**10
a1 = 0.027
b1 = 1
c1 = 0.8
d1 = popn[0]
t1 = np.cumsum(np.ones(n1)*dt)
sol1 = odeint(pop_res_eqns, [P_01, R_01], t1, args=(a1, b1, c1, d1))
P1, R1 = sol1[:, 0], sol1[:, 1]

k = 4
n2 = dates[-1]-dates[k]
dates2 = np.arange(dates[k],dates[-1],1)
P_02 = popn[k]
R_02 = R1[-1]
print(R_02)
a2 = 0.043
b2 = 1
c2 = 0.8
d2 = popn[0]
t2 = t1[-1]+np.cumsum(np.ones(n2)*dt)
sol2 = odeint(pop_res_eqns, [P_02, R_02], t2, args=(a2, b2, c2, d2))
P2, R2 = sol2[:, 0], sol2[:, 1]

fig, ax = plt.subplots() 

ax.plot(dates,popn,'o', label = 'Population Data')
ax.plot(dates1,P1, label = r'$\alpha={}$'.format(a1))
ax.plot(dates2,P2, label = r'$\alpha={}$'.format(a2))

leg=1
font_sizes = [12,12,12,12,12]
labels=['Year','Population',font_sizes,leg]
plotting(ax,*labels).add_labels()
ax.set_yscale('log')
# Out:
# 27497998961.3962

# %%
fig, ax = plt.subplots() 

k = 20
n3 = dates[-1]-dates[k]
dates3 = np.arange(dates[k],dates[-1],1)
P_03 = popn[k]
R_03 = R2[-1]
print(R_03)
a3 = 0.11
b3 = 1
c3 = 0.8
d3 = popn[0]
t3 = t2[-1]+np.cumsum(np.ones(n3)*dt)
sol3 = odeint(pop_res_eqns, [P_03, R_03], t3, args=(a3, b3, c3, d3))
P3, R3 = sol3[:, 0], sol3[:, 1]

k = 20
ax.plot(dates[k:],popn[k:],'o', label = 'Data')
ax.plot(dates3,P3, label = r'$\alpha={}$'.format(a3))
leg=1
font_sizes = [12,12,12,12,12]
labels=['Year','Population',font_sizes,leg]
plotting(ax,*labels).add_labels()
ax.set_yscale('log')
# Out:
# 21482415460.64862

# %%
fig, ax = plt.subplots() 

k = 30
n4 = dates[-1]-dates[k]
dates4 = np.arange(dates[k],dates[-1],1)
P_04 = popn[k]
R_04 = R3[-1]
print(R_04)
a4 = 0.62
b4 = 1
c4 = 0.8
d4 = popn[0]
t4 = t3[-1]+np.cumsum(np.ones(n4)*dt)
sol4 = odeint(pop_res_eqns, [P_04, R_04], t4, args=(a4, b4, c4, d4))
P4, R4 = sol4[:, 0], sol4[:, 1]

k = 100
n5 = dates[-1]-dates[k]
dates5 = np.arange(dates[k],dates[-1],1)
P_05 = popn[k]
R_05 = R4[-1]
print(R_05)
a5 = 0.8
b5 = 1
c5 = 0.8
d5 = popn[0]
t5 = t4[-1]+np.cumsum(np.ones(n5)*dt)
sol5 = odeint(pop_res_eqns, [P_05, R_05], t5, args=(a5, b5, c5, d5))
P5, R5 = sol5[:, 0], sol5[:, 1]

k = 150
n6 = dates[-1]-dates[k]
dates6 = np.arange(dates[k],dates[-1],1)
P_06 = popn[k]
R_06 = R5[-1]
print(R_06)
a6 = 1.2
b6 = 1
c6 = 0.8
d6 = popn[0]
t6 = t5[-1]+np.cumsum(np.ones(n6)*dt)
sol6 = odeint(pop_res_eqns, [P_06, R_06], t6, args=(a6, b6, c6, d6))
P6, R6 = sol6[:, 0], sol6[:, 1]

k = 186
n7 = dates[-1]-dates[k]
dates7 = np.arange(dates[k],dates[-1],1)
P_07 = popn[k]
R_07 = R6[-1]
print(R_06)
a7 = 2.4
b7 = 1
c7 = 0.8
d7 = popn[0]
t7 = t6[-1]+np.cumsum(np.ones(n7)*dt)
sol7 = odeint(pop_res_eqns, [P_07, R_07], t7, args=(a7, b7, c7, d7))
P7, R7 = sol7[:, 0], sol7[:, 1]


k = 30
ax.plot(dates[k:],popn[k:],'o', label = 'Data')
ax.plot(dates4,P4, label = r'$\alpha={}$'.format(a4))
ax.plot(dates5,P5, label = r'$\alpha={}$'.format(a5))
ax.plot(dates6,P6, label = r'$\alpha={}$'.format(a6))
ax.plot(dates7,P7, label = r'$\alpha={}$'.format(a7))

leg=1
font_sizes = [12,12,12,12,12]
labels=['Year','Population',font_sizes,leg]
plotting(ax,*labels).add_labels()
ax.set_yscale('log')
# Out:
# 17275194923.70853
# 13566355146.836514
# 10728406066.931519
# 10728406066.931519

# %%
fig, ax = plt.subplots(2,2,figsize=(10,5)) 

ax[0,0].plot(dates,popn,'o', label = 'Data')
ax[0,0].plot(dates1,P1, label = r'$\alpha={}$'.format(a1), color = 'tab:orange')
ax[0,0].plot(dates2,P2, label = r'$\alpha={}$'.format(a2), color = 'tab:green')

# ax.plot(dates1,Rs1, label = 'Resources')

leg=1
font_sizes = [10,10,10,10,10]
labels=['Year','Population',font_sizes,leg]
plotting(ax[0,0],*labels).add_labels()
ax[0,0].set_yscale('log')

k = 20
ax[0,1].plot(dates[k:],popn[k:],'o', label = 'Data')
ax[0,1].plot(dates3,P3, label = r'$\alpha={}$'.format(a3), color = 'tab:red')
leg=1
labels=['Year','Population',font_sizes,leg]
plotting(ax[0,1],*labels).add_labels()
ax[0,1].set_yscale('log')

k = 30
ax[1,0].plot(dates[k:],popn[k:],'o', label = 'Data')
ax[1,0].plot(dates4,P4, label = r'$\alpha={}$'.format(a4), color = 'tab:purple')
ax[1,0].plot(dates5,P5, label = r'$\alpha={}$'.format(a5), color = 'tab:brown')
ax[1,0].plot(dates6,P6, label = r'$\alpha={}$'.format(a6), color = 'tab:pink')
ax[1,0].plot(dates7,P7, label = r'$\alpha={}$'.format(a7), color = 'tab:grey')
leg=1
labels=['Year','Population',font_sizes,leg]
plotting(ax[1,0],*labels).add_labels()
ax[1,0].set_yscale('log')

ax[1,1].axis('off')


plt.tight_layout()

# %%
k = 186
dates_f = 2500
nf = dates_f-dates[k]
dates_fs = np.arange(dates[k],dates_f,1)
print(len(dates_f1))
P_0f = popn[k]
R_0f = R6[-1]
tf = t6[-1]+np.cumsum(np.ones(nf)*dt)
df = popn[0]

abc1 = [2.35, 1, 0.8]
abc2 = [2.6, 1.5, 0.4]
abc3 = [2.9, 2, 0.2]
abc4 = [3.3, 2.5, 0.1]


sol_f1 = odeint(pop_res_eqns, [P_0f, R_0f], tf, args=(*abc1, d))
Pf1, Rf1 = sol_f1[:, 0], sol_f1[:, 1]

sol_f2 = odeint(pop_res_eqns, [P_0f, R_0f], tf, args=(*abc2, d))
Pf2, Rf2 = sol_f2[:, 0], sol_f2[:, 1]

sol_f3 = odeint(pop_res_eqns, [P_0f, R_0f], tf, args=(*abc3, d))
Pf3, Rf3 = sol_f3[:, 0], sol_f3[:, 1]

sol_f4 = odeint(pop_res_eqns, [P_0f, R_0f], tf, args=(*abc4, d))
Pf4, Rf4 = sol_f4[:, 0], sol_f4[:, 1]

fig, ax = plt.subplots() 

k = 30
ax.plot(dates[k:],popn[k:],'o', label = 'Data')
ax.plot(dates_fs,Pf1, label = r'$\alpha = {}, \beta = {}$'.format(abc1[0],abc1[1])+'\n'+r'$\gamma = {}$'.format(abc1[2]))
ax.plot(dates_fs,Pf2, label = r'$\alpha = {}, \beta = {}, \gamma = {}$'.format(abc2[0],abc2[1],abc2[2]))
ax.plot(dates_fs,Pf3, label = r'$\alpha = {}, \beta = {}, \gamma = {}$'.format(abc3[0],abc3[1],abc3[2]))
ax.plot(dates_fs,Pf4, label = r'$\alpha = {}, \beta = {}, \gamma = {}$'.format(abc4[0],abc4[1],abc4[2]))

leg=1
font_sizes = [12,12,12,12,9]
labels=['Year','Population',font_sizes,leg]
plotting(ax,*labels).add_labels()
# ax.set_yscale('log')

plt.tight_layout()
# Out:
# 551

# %%
plt.plot(Rf1)
plt.plot(Rf2)
